# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
query = 'rice'

# %%
url = f'https://www.daraz.com.np/catalog/?q={query}'

# %%
res = requests.get(url).content

# %%
soup = bs(res, 'html.parser')

# %%
soup.find("div")
# Out:
# <div class="mui-zebra-module" data-module-id="2553362700" data-spm="2553362700" data-version="5.4.27" id="J_2553362700">
# <!-- columns: "0.1.0" -->
# <link href="//laz-g-cdn.alicdn.com/lazada-search-fe/daraz-searchbox/0.1.0/index.css" rel="stylesheet">
# <script src="//laz-g-cdn.alicdn.com/lazada-search-fe/daraz-searchbox/0.1.0/index.js"></script>
# <script>
#   window.g_config = window.g_config || {};
#   window.g_config.voyagerVersion = '2';
#   window.g_config.voyagerEnv = 'IDC';
#   window.g_config.channel = 'default';
# </script>
# <div class="site-nav J_NavScroll" data-config="{}" data-mod-name="@ali/lzdmod-site-nav-pc-daraz/pc/index" id="J_LzdSiteNav">
# <div class="yatra-header">
# <div class="lzd-header lzd-header-full" data-spm="header" data-tag="links">
# <div class="lzd-header-content-wrap J_NavScroll" id="topActionHeader">
# <div class="lzd-header-content">
# <div class="lzd-links-bar" id="topActionLinks">
# <div class="links-list header-content NP en">
# ...

# %%
#root > div > div.ant-row.main--pIV2h > div > div > div.ant-col-20.ant-col-push-4.side-right--Tyehf > div.box--ujueT > div:nth-child(2) > div > div > div.info--ifj7U > div.title--wFj93

# %%
soup.find_all("div")
# Out:
# [<div class="mui-zebra-module" data-module-id="2553362700" data-spm="2553362700" data-version="5.4.27" id="J_2553362700">
#  <!-- columns: "0.1.0" -->
#  <link href="//laz-g-cdn.alicdn.com/lazada-search-fe/daraz-searchbox/0.1.0/index.css" rel="stylesheet">
#  <script src="//laz-g-cdn.alicdn.com/lazada-search-fe/daraz-searchbox/0.1.0/index.js"></script>
#  <script>
#    window.g_config = window.g_config || {};
#    window.g_config.voyagerVersion = '2';
#    window.g_config.voyagerEnv = 'IDC';
#    window.g_config.channel = 'default';
#  </script>
#  <div class="site-nav J_NavScroll" data-config="{}" data-mod-name="@ali/lzdmod-site-nav-pc-daraz/pc/index" id="J_LzdSiteNav">
#  <div class="yatra-header">
#  <div class="lzd-header lzd-header-full" data-spm="header" data-tag="links">
#  <div class="lzd-header-content-wrap J_NavScroll" id="topActionHeader">
#  <div class="lzd-header-content">
#  <div class="lzd-links-bar" id="topActionLinks">
# ...

# %%
print(soup.find('div', attrs= {'class':'title--wFj93'}))
# Out:
# None

# %%
soup.find_all("div", {"class": "tag--huSJx"})
# Out:
# []

# %%
soup.find_all("div", {"id": "products"})
# Out:
# []

# %%
#root > div > div.ant-row.main--pIV2h > div > div > div.ant-col-20.ant-col-push-4.side-right--Tyehf > div.box--ujueT > div:nth-child(1) > div > div > div.info--ifj7U > div.title--wFj93

# %%
<div class="title--wFj93"><a age="0" href="//www.daraz.com.np/products/sara-foods-sama-rice-500gm-i116523835-s1031888401.html?spm=a2a0e.searchlist.list.2.68efaac78E3dvD&amp;search=1" title="Sara Foods Sama Rice - 500gm" data-spm-anchor-id="a2a0e.searchlist.list.2">Sara Foods Sama Rice - 500gm</a></div>
# Out:
# []
